# %%
pip install huspacy
# Out:
# ...
#   Using cached pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached pyparsing-3.2.1-py3-none-any.whl (107 kB)
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda 25.1.1 requires conda-libmamba-solver>=24.11.0, but you have conda-libmamba-solver 24.9.0 which is incompatible.
# conda 25.1.1 requires packaging>=23.0, but you have packaging 21.3 which is incompatible.
# langchain-core 0.3.35 requires packaging<25,>=23.2, but you have packaging 21.3 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import huspacy

# Download the latest CPU optimized model
huspacy.download()
# Out:
# ['/home/tamas/micromamba/bin/python', '-m', 'pip', 'install', 'hu_core_news_lg @ https://huggingface.co/huspacy/hu_core_news_lg/resolve/v3.8.0/hu_core_news_lg-any-py3-none-any.whl']
# ...
#      ━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━ 161.7/401.5 MB 1.2 MB/s eta 0:03:28
# ERROR: Operation cancelled by user
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import huspacy
#       3 # Download the latest CPU optimized model
# ----> 4 huspacy.download()
#
# File ~/micromamba/lib/python3.9/site-packages/huspacy/__init__.py:83, in download(model_name, model_version)
#      81 cmd = [sys.executable, "-m", "pip", "install"] + [model_name + " @ " + download_url]
#      82 print(cmd)
# ---> 83 run_command(cmd)
#
# File ~/micromamba/lib/python3.9/site-packages/huspacy/utils.py:28, in run_command(cmd_list, stdin, capture)
#      26 cmd_str = " ".join(cmd_list)
# ...

# %%
import huspacy

# Download the latest CPU optimized model
huspacy.download()

# Load the model using spacy.load(...)
import spacy

nlp = spacy.load("hu_core_news_lg")

# Load the default large model

nlp = huspacy.load()

# Easily process text
doc = nlp("question")
# Out:
# ['/home/tamas/micromamba/bin/python', '-m', 'pip', 'install', 'hu_core_news_lg @ https://huggingface.co/huspacy/hu_core_news_lg/resolve/v3.8.0/hu_core_news_lg-any-py3-none-any.whl']
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.5/401.5 MB 1.5 MB/s eta 0:00:0000:0100:10
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 7
#       4 huspacy.download()
#       6 # Load the model using spacy.load(...)
# ----> 7 import spacy
#       9 nlp = spacy.load("hu_core_news_lg")
#      11 # Load the default large model
#
# File ~/micromamba/lib/python3.9/site-packages/spacy/__init__.py:13
#      10 # These are imported as part of the API
#      11 from thinc.api import Config, prefer_gpu, require_cpu, require_gpu  # noqa: F401
# ---> 13 from . import pipeline  # noqa: F401
#      14 from . import util
#      15 from .about import __version__  # noqa: F401
#
# ...
